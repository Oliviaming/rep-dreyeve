# %%
from __future__ import division
from keras.optimizers import SGD

from callbacks import get_callbacks

from model import ml_net_model, loss
from batch_generators import generate_batch

from config import shape_c, shape_r, batchsize
from config import nb_samples_per_epoch, nb_epoch, nb_imgs_val

# %%
if __name__ == '__main__':

    model = ml_net_model(img_cols=shape_c, img_rows=shape_r, downsampling_factor_product=10)
    sgd = SGD(learning_rate=1e-3, decay=0.0005, momentum=0.9, nesterov=True)
    print("Compile ML-Net Model")
    model.compile(sgd, loss)
    model.summary()

    print("Training ML-Net")
    model.fit(x=generate_batch(batchsize=batchsize, mode='train', gt_type='fix'),
                        validation_data=generate_batch(batchsize=batchsize, mode='val', gt_type='fix'),
                        validation_steps=nb_imgs_val // batchsize,  # Adjust the validation steps according to your dataset
                        epochs=nb_epoch,
                        steps_per_epoch=nb_samples_per_epoch // batchsize,  # Adjust the steps per epoch according to your dataset
                        callbacks=get_callbacks())
# Out:
# This experiment on experiment_id: 2025-02-14_19-28-10
# No checkpoint found. Loading VGG16 weights instead.
# Layer 1 weights - min: -0.6714000701904297, max: 0.6085159182548523
# Layer 3 weights - min: -0.21561293303966522, max: 0.2891709506511688
# Layer 6 weights - min: -0.33594822883605957, max: 0.41661107540130615
# Layer 8 weights - min: -0.1819043755531311, max: 0.277375727891922
# Layer 11 weights - min: -0.183063343167305, max: 0.5444108247756958
# Layer 13 weights - min: -0.17710502445697784, max: 0.45931634306907654
# Layer 15 weights - min: -0.17968426644802094, max: 0.3915373682975769
# Layer 18 weights - min: -0.12409957498311996, max: 0.3138822615146637
# Layer 20 weights - min: -0.10524698346853256, max: 0.337660014629364
# Layer 22 weights - min: -0.12739665806293488, max: 0.2562357187271118
# Layer 25 weights - min: -0.11329856514930725, max: 0.19044439494609833
# Layer 27 weights - min: -0.13681107759475708, max: 0.2051512748003006
# Layer 29 weights - min: -0.09288482367992401, max: 0.28699666261672974
# WARNING:tensorflow:From c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\keras\src\backend\tensorflow\core.py:216: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Compile ML-Net Model
# c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\keras\src\optimizers\base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 480, 640,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 480, 640,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 480, 640,  │     36,928 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 240, 320,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 240, 320,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 240, 320,  │    147,584 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 120, 160,  │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 120, 160,  │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 120, 160,  │    590,080 │ conv2d_4[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 120, 160,  │    590,080 │ conv2d_5[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 60, 80,    │          0 │ conv2d_6[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 60, 80,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 60, 80,    │  2,359,808 │ conv2d_7[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 60, 80,    │  2,359,808 │ conv2d_8[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 60, 80,    │          0 │ conv2d_9[0][0]    │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 60, 80,    │  2,359,808 │ max_pooling2d_3[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 60, 80,    │  2,359,808 │ conv2d_10[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 60, 80,    │  2,359,808 │ conv2d_11[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 60, 80,    │    131,328 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 60, 80,    │    131,328 │ conv2d_12[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 60, 80,    │          0 │ max_pooling2d_2[… │
# │ (Concatenate)       │ 768)              │            │ conv2d_13[0][0],  │
# │                     │                   │            │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 60, 80,    │          0 │ concatenate[0][0] │
# │                     │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 60, 80,    │    442,432 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 60, 80, 1) │         65 │ conv2d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ elt_wise_product    │ (None, 60, 80, 8) │         48 │ conv2d_16[0][0]   │
# │ (EltWiseProduct)    │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 60, 80, 8) │          0 │ elt_wise_product… │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 15,419,889 (58.82 MB)
#  Trainable params: 15,419,889 (58.82 MB)
#  Non-trainable params: 0 (0.00 B)
# Training ML-Net
# Saved experiment id: 2025-02-14_19-28-41
# load batch X - min: 0.0, max: 0.6509257021037581
# load batch Y - min: 0.0, max: 0.7843137383460999
# load batch X - min: 0.0, max: 0.7870431040645424
# load batch Y - min: 0.0, max: 0.7764706015586853
# load batch X - min: 0.0, max: 0.700047665185866
# load batch Y - min: 0.0, max: 0.8313725590705872
# c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(10, 480, 640, 3))
#   warnings.warn(msg)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Model predictions (P) - min: 0.7620091438293457, max: 1.0
# Model input (X) - min: 0.0, max: 0.7000476717948914
# Model ground truth (Y) - min: 0.0, max: 0.8313725590705872
# x min/max: 0, 255
# P shape: (10, 60, 80, 8)
# Input to postprocess_predictions - min: 0.985419511795044, max: 0.9997206926345825
# Output of postprocess_predictions - min: 0.9891118407249451, max: 0.9891125559806824
# before Normal p min/max: 254.99981689453125, 255.0
# p min/max: 0, 255
# Y shape: (10, 60, 80, 1)
# Input to postprocess_predictions - min: 0.0, max: 0.0
# Warning: max value is 0 in postprocess_predictions
# before Normal y min/max: 0.0, 0.0
# y min/max: 0, 0
# x min/max: 0, 255
# P shape: (10, 60, 80, 8)
# Input to postprocess_predictions - min: 0.985252320766449, max: 0.9997191429138184
# Output of postprocess_predictions - min: 0.9893184900283813, max: 0.9893184900283813
# before Normal p min/max: 255.0, 255.0
# p min/max: 0, 0
# Y shape: (10, 60, 80, 1)
# Input to postprocess_predictions - min: 0.0, max: 0.0
# Warning: max value is 0 in postprocess_predictions
# before Normal y min/max: 0.0, 0.0
# y min/max: 0, 0
# x min/max: 0, 255
# P shape: (10, 60, 80, 8)
# Input to postprocess_predictions - min: 0.9854173064231873, max: 0.9997206926345825
# Output of postprocess_predictions - min: 0.989109456539154, max: 0.9891132116317749
# before Normal p min/max: 254.9990234375, 255.0
# p min/max: 0, 255
# Y shape: (10, 60, 80, 1)
# Input to postprocess_predictions - min: 0.0, max: 0.0
# Warning: max value is 0 in postprocess_predictions
# before Normal y min/max: 0.0, 0.0
# y min/max: 0, 0
# x min/max: 0, 255
# P shape: (10, 60, 80, 8)
# Input to postprocess_predictions - min: 0.9854304194450378, max: 0.9997211694717407
# Output of postprocess_predictions - min: 0.9891119599342346, max: 0.9891128540039062
# before Normal p min/max: 254.99977111816406, 255.0
# p min/max: 0, 255
# Y shape: (10, 60, 80, 1)
# Input to postprocess_predictions - min: 0.0, max: 0.0
# Warning: max value is 0 in postprocess_predictions
# before Normal y min/max: 0.0, 0.0
# y min/max: 0, 0
# x min/max: 0, 255
# P shape: (10, 60, 80, 8)
# Input to postprocess_predictions - min: 0.9852715134620667, max: 0.9997192025184631
# Output of postprocess_predictions - min: 0.9891971349716187, max: 0.9892064929008484
# before Normal p min/max: 254.99758911132812, 255.0
# p min/max: 0, 255
# Y shape: (10, 60, 80, 1)
# Input to postprocess_predictions - min: 0.0, max: 0.0
# Warning: max value is 0 in postprocess_predictions
# before Normal y min/max: 0.0, 0.0
# y min/max: 0, 0
# x min/max: 0, 255
# P shape: (10, 60, 80, 8)
# Input to postprocess_predictions - min: 0.9853923320770264, max: 0.9997201561927795
# Output of postprocess_predictions - min: 0.9891046285629272, max: 0.9891132116317749
# before Normal p min/max: 254.99778747558594, 255.0
# p min/max: 0, 255
# Y shape: (10, 60, 80, 1)
# Input to postprocess_predictions - min: 0.0, max: 0.0
# Warning: max value is 0 in postprocess_predictions
# before Normal y min/max: 0.0, 0.0
# y min/max: 0, 0
# x min/max: 0, 255
# P shape: (10, 60, 80, 8)
# Input to postprocess_predictions - min: 0.985426664352417, max: 0.9997209310531616
# Output of postprocess_predictions - min: 0.9891068339347839, max: 0.9891113042831421
# before Normal p min/max: 254.99884033203125, 255.0
# p min/max: 0, 255
# Y shape: (10, 60, 80, 1)
# Input to postprocess_predictions - min: 0.0, max: 0.0
# Warning: max value is 0 in postprocess_predictions
# before Normal y min/max: 0.0, 0.0
# y min/max: 0, 0
# x min/max: 0, 255
# P shape: (10, 60, 80, 8)
# Input to postprocess_predictions - min: 0.9854329824447632, max: 0.9997211694717407
# Output of postprocess_predictions - min: 0.9890967011451721, max: 0.9890992045402527
# before Normal p min/max: 254.99935913085938, 255.0
# p min/max: 0, 255
# Y shape: (10, 60, 80, 1)
# Input to postprocess_predictions - min: 0.0, max: 0.0
# Warning: max value is 0 in postprocess_predictions
# before Normal y min/max: 0.0, 0.0
# y min/max: 0, 0
# x min/max: 0, 255
# P shape: (10, 60, 80, 8)
# Input to postprocess_predictions - min: 0.9854264855384827, max: 0.9997208118438721
# Output of postprocess_predictions - min: 0.9891040921211243, max: 0.98911052942276
# before Normal p min/max: 254.9983367919922, 255.0
# p min/max: 0, 255
# Y shape: (10, 60, 80, 1)
# Input to postprocess_predictions - min: 0.0, max: 0.0
# Warning: max value is 0 in postprocess_predictions
# before Normal y min/max: 0.0, 0.0
# y min/max: 0, 0
# x min/max: 0, 255
# P shape: (10, 60, 80, 8)
# Input to postprocess_predictions - min: 0.9854326248168945, max: 0.9997209906578064
# Output of postprocess_predictions - min: 0.9890909790992737, max: 0.9890928864479065
# before Normal p min/max: 254.99951171875, 255.0
# p min/max: 0, 255
# Y shape: (10, 60, 80, 1)
# Input to postprocess_predictions - min: 0.0, max: 0.0
# Warning: max value is 0 in postprocess_predictions
# before Normal y min/max: 0.0, 0.0
# y min/max: 0, 0
# Epoch 1/2
# c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 480, 640, 3))
#   warnings.warn(msg)
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 15s 15s/step - loss: 0.9582load batch X - min: 0.0, max: 0.651956561478758
# load batch Y - min: 0.0, max: 0.7529411911964417
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 10
#       7 model.summary()
#       9 print("Training ML-Net")
# ---> 10 model.fit(x=generate_batch(batchsize=batchsize, mode='train', gt_type='fix'),
#      11                     validation_data=generate_batch(batchsize=batchsize, mode='val', gt_type='fix'),
#      12                     validation_steps=nb_imgs_val // batchsize,  # Adjust the validation steps according to your dataset
#      13                     epochs=nb_epoch,
#      14                     steps_per_epoch=nb_samples_per_epoch // batchsize,  # Adjust the steps per epoch according to your dataset
#      15                     callbacks=get_callbacks())
#
# File c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File c:\Users\SCTW54265\anaconda3\envs\tf_gpu\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
